# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharad-18/Next_word_prediction_MODEL_using_LSTM/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
faqs="""
Exploring Long Short-Term Memory (LSTM) for Text Prediction: Techniques, Applications, and Challenges.
Abstract: In the realm of natural language processing (NLP), text prediction stands as a fundamental task with applications ranging from language modeling to autocomplete systems and predictive typing.
Among the various techniques employed for text prediction, Long Short-Term Memory (LSTM) networks have emerged as a powerful tool, capable of capturing long-range dependencies and preserving context over extended sequences.
This essay delves into the principles, methodologies, applications, and challenges associated with LSTM-based text prediction, exploring its significance in modern NLP research and applications.
Introduction: Text prediction, also known as language modeling or next-word prediction, refers to the task of predicting the next word or sequence of words in a given text based on the preceding context.
This task plays a pivotal role in various NLP applications, including machine translation, speech recognition, sentiment analysis, and autocomplete systems.
Traditional methods for text prediction often rely on statistical language models or n-gram models, which suffer from limited contextual understanding and struggle to capture long-range dependencies within the text.
In recent years, deep learning approaches, particularly recurrent neural networks (RNNs) and their variants, have demonstrated remarkable performance in text prediction tasks.
Among these variants, LSTM networks have garnered significant attention due to their ability to mitigate the vanishing gradient problem and capture long-term dependencies in sequential data.
LSTM networks, with their gated architecture, offer an effective solution for modeling sequential data with complex temporal dynamics, making them well-suited for text prediction tasks.
Principles of LSTM: LSTM networks are a type of recurrent neural network architecture designed to overcome the limitations of traditional RNNs in capturing long-range dependencies.
At the core of LSTM networks are memory cells equipped with various gates, including input gates, forget gates, and output gates.
These gates regulate the flow of information within the network, allowing it to retain relevant information over long sequences while filtering out irrelevant information.
The key components of an LSTM cell include: Forget Gate: Determines which information from the previous cell state should be discarded or forgotten.
Input Gate: Determines which new information from the current input should be stored in the cell state.
Cell State: Represents the long-term memory of the network, preserving information across time steps.
Output Gate: Determines which information from the current cell state should be output to the next time step.
By learning to selectively update and propagate information through the gates, LSTM networks can effectively capture long-term dependencies and retain contextual information over extended sequences, making them well-suited for text prediction tasks.
Methodologies for LSTM-based Text Prediction: LSTM-based text prediction involves several key methodologies and techniques aimed at training, evaluating, and deploying predictive models.
These methodologies include: Data Preparation: Preprocessing and tokenization of text data, including text cleaning, tokenization, and sequence padding.
Model Architecture: Designing the architecture of the LSTM network, including the number of layers, hidden units, and embedding dimensions.
Training Procedure: Training the LSTM model using backpropagation through time (BPTT) or truncated BPTT with optimization techniques such as stochastic gradient descent (SGD) or Adam.
Hyperparameter Tuning: Optimizing hyperparameters such as learning rate, dropout rate, and batch size to improve model performance.
Evaluation Metrics: Assessing model performance using evaluation metrics such as perplexity, cross-entropy loss, and accuracy on held-out validation or test sets.
Fine-Tuning and Transfer Learning: Fine-tuning pre-trained LSTM models on domain-specific data or using transfer learning techniques to leverage pre-trained language models for text prediction tasks.
Applications of LSTM-based Text Prediction: LSTM-based text prediction finds applications across various domains and industries, including: Autocomplete Systems: Providing real-time suggestions for the next word or phrase in text input fields, enhancing user experience in search engines, messaging apps, and code editors.
Speech Recognition: Predicting the next word or sentence in speech recognition systems, improving transcription accuracy and naturalness in speech-to-text applications.
Language Modeling: Generating coherent and contextually relevant text based on a given prompt or seed text, enabling applications such as chatbots, virtual assistants, and content generation.
Machine Translation: Predicting the next word or phrase in machine translation systems, facilitating the translation of text between different languages with improved fluency and coherence.
Sentiment Analysis: Predicting the sentiment or emotion of text inputs, aiding in sentiment analysis tasks such as opinion mining, social media monitoring, and customer feedback analysis.
Challenges and Future Directions: Despite the significant progress and success achieved with LSTM-based text prediction, several challenges and areas for improvement remain: Handling Long-Term Dependencies: While LSTM networks excel at capturing long-term dependencies, they may still struggle with extremely long sequences or contexts, leading to information loss or forgetting.
Overfitting and Generalization: LSTM models are prone to overfitting, especially when trained on limited data or noisy text corpora.
Techniques such as regularization, dropout, and data augmentation can help alleviate overfitting and improve generalization.
Computational Efficiency: Training and deploying large-scale LSTM models can be computationally intensive, requiring significant computational resources and memory.
Efficient model architectures and optimization techniques are needed to address these challenges.
Interpretability and Explainability: LSTM models are often viewed as black-box models, making it challenging to interpret their internal workings and decision-making processes.
Methods for interpreting and explaining model predictions are essential for building trust and understanding in LSTM-based text prediction systems.
Conclusion: In conclusion, LSTM-based text prediction represents a powerful approach for modeling and generating text with rich contextual understanding and long-term dependencies.
By leveraging the principles of gated recurrent networks, LSTM models have demonstrated superior performance in various text prediction tasks across different domains and applications.
However, addressing challenges such as handling long-term dependencies, overfitting, and computational efficiency remains crucial for advancing the state-of-the-art in LSTM-based text prediction.
With ongoing research and innovation, LSTM networks are poised to play an increasingly significant role in shaping the future of natural language processing and intelligent text-based applications.
References:
Hochreiter, S., & Schmidhuber, J. (1997). Long short-term memory. Neural computation, 9(8), 1735-1780.
Graves, A. (2013). Generating sequences with recurrent neural networks. arXiv preprint arXiv:1308.0850.
Karpathy, A., & Fei-Fei, L. (2015). Visualizing and understanding recurrent networks. arXiv preprint arXiv:1506.02078.
Bahdanau, D., Cho, K., & Bengio, Y. (2014). Neural machine translation by jointly learning to align and translate. arXiv preprint arXiv:1409.0473.
Vaswani, A., Shazeer, N., Parmar, N., Uszkoreit, J., Jones, L., Gomez, A. N., ... & Polosukhin, I. (2017). Attention is all you need. In Advances in neural information processing systems (pp. 5998
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer=Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 431

# %%
input_sequence=[]
for sentence in faqs.split('\n'):
  tokenized_sentence=tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequence.append(tokenized_sentence[:i+1])

# %%
input_sequence
# Out:
# [[97, 10],
#  [97, 10, 70],
#  [97, 10, 70, 19],
#  [97, 10, 70, 19, 28],
#  [97, 10, 70, 19, 28, 4],
#  [97, 10, 70, 19, 28, 4, 11],
#  [97, 10, 70, 19, 28, 4, 11, 3],
#  [97, 10, 70, 19, 28, 4, 11, 3, 6],
#  [97, 10, 70, 19, 28, 4, 11, 3, 6, 22],
#  [97, 10, 70, 19, 28, 4, 11, 3, 6, 22, 15],
#  [97, 10, 70, 19, 28, 4, 11, 3, 6, 22, 15, 1],
#  [97, 10, 70, 19, 28, 4, 11, 3, 6, 22, 15, 1, 29],
#  [163, 5],
#  [163, 5, 2],
#  [163, 5, 2, 164],
#  [163, 5, 2, 164, 7],
#  [163, 5, 2, 164, 7, 98],
#  [163, 5, 2, 164, 7, 98, 23],
#  [163, 5, 2, 164, 7, 98, 23, 71],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3, 6],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3, 6, 165],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3, 6, 165, 16],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3, 6, 165, 16, 17],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3, 6, 165, 16, 17, 166],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3, 6, 165, 16, 17, 166, 73],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3, 6, 165, 16, 17, 166, 73, 12],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3, 6, 165, 16, 17, 166, 73, 12, 15],
#  [163, 5, 2, 164, 7, 98, 23, 71, 72, 3, 6, 165, 16, 17, 166, 73, 12, 15, 167],
#  [163,
#   5,
#   2,
#   164,
#   7,
#   98,
#   23,
#   71,
#   72,
#   3,
#   6,
#   165,
#   16,
#   17,
#   166,
#   73,
#   12,
#   15,
#   167,
#   38],
#  [163,
#   5,
#   2,
#   164,
#   7,
#   98,
#   23,
#   71,
#   72,
#   3,
#   6,
#   165,
#   16,
#   17,
#   166,
#   73,
#   12,
#   15,
#   167,
#   38,
#   23],
#  [163,
#   5,
#   2,
#   164,
#   7,
#   98,
#   23,
#   71,
#   72,
#   3,
#   6,
#   165,
#   16,
#   17,
#   166,
#   73,
#   12,
#   15,
#   167,
#   38,
#   23,
#   39],
#  [163,
#   5,
#   2,
#   164,
#   7,
#   98,
#   23,
#   71,
#   72,
#   3,
#   6,
#   165,
#   16,
#   17,
#   166,
#   73,
#   12,
#   15,
#   167,
#   38,
#   23,
#   39,
#   8],
#  [163,
#   5,
#   2,
#   164,
#   7,
#   98,
#   23,
#   71,
#   72,
#   3,
#   6,
#   165,
#   16,
#   17,
#   166,
#   73,
#   12,
#   15,
#   167,
#   38,
#   23,
#   39,
#   8,
#   74],
#  [163,
#   5,
#   2,
#   164,
#   7,
#   98,
#   23,
#   71,
#   72,
#   3,
#   6,
#   165,
#   16,
#   17,
#   166,
#   73,
#   12,
#   15,
#   167,
#   38,
#   23,
#   39,
#   8,
#   74,
#   24],
#  [163,
#   5,
#   2,
#   164,
#   7,
#   98,
#   23,
#   71,
#   72,
#   3,
#   6,
#   165,
#   16,
#   17,
#   166,
#   73,
#   12,
#   15,
#   167,
#   38,
#   23,
#   39,
#   8,
#   74,
#   24,
#   1],
#  [163,
#   5,
#   2,
#   164,
#   7,
#   98,
#   23,
#   71,
#   72,
#   3,
#   6,
#   165,
#   16,
#   17,
#   166,
#   73,
#   12,
#   15,
#   167,
#   38,
#   23,
#   39,
#   8,
#   74,
#   24,
#   1,
#   99],
#  [163,
#   5,
#   2,
#   164,
#   7,
#   98,
#   23,
#   71,
#   72,
#   3,
#   6,
#   165,
#   16,
#   17,
#   166,
#   73,
#   12,
#   15,
#   167,
#   38,
#   23,
#   39,
#   8,
#   74,
#   24,
#   1,
#   99,
#   168],
#  [100, 2],
#  [100, 2, 40],
#  [100, 2, 40, 22],
#  [100, 2, 40, 22, 169],
#  [100, 2, 40, 22, 169, 11],
#  [100, 2, 40, 22, 169, 11, 3],
#  [100, 2, 40, 22, 169, 11, 3, 6],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70, 19],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70, 19, 28],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70, 19, 28, 4],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70, 19, 28, 4, 13],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70, 19, 28, 4, 13, 48],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70, 19, 28, 4, 13, 48, 170],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70, 19, 28, 4, 13, 48, 170, 16],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70, 19, 28, 4, 13, 48, 170, 16, 17],
#  [100, 2, 40, 22, 169, 11, 3, 6, 10, 70, 19, 28, 4, 13, 48, 170, 16, 17, 101],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75,
#   10],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75,
#   10,
#   76],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75,
#   10,
#   76,
#   21],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75,
#   10,
#   76,
#   21,
#   1],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75,
#   10,
#   76,
#   21,
#   1,
#   102],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75,
#   10,
#   76,
#   21,
#   1,
#   102,
#   103],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75,
#   10,
#   76,
#   21,
#   1,
#   102,
#   103,
#   77],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75,
#   10,
#   76,
#   21,
#   1,
#   102,
#   103,
#   77,
#   104],
#  [100,
#   2,
#   40,
#   22,
#   169,
#   11,
#   3,
#   6,
#   10,
#   70,
#   19,
#   28,
#   4,
#   13,
#   48,
#   170,
#   16,
#   17,
#   101,
#   171,
#   172,
#   7,
#   75,
#   10,
#   76,
#   21,
#   1,
#   102,
#   103,
#   77,
#   104,
#   41],
#  [105, 173],
#  [105, 173, 174],
#  [105, 173, 174, 175],
#  [105, 173, 174, 175, 2],
#  [105, 173, 174, 175, 2, 78],
#  [105, 173, 174, 175, 2, 78, 49],
#  [105, 173, 174, 175, 2, 78, 49, 15],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1, 29],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1, 29, 176],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1, 29, 176, 12],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1, 29, 176, 12, 4],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1, 29, 176, 12, 4, 14],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1, 29, 176, 12, 4, 14, 3],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1, 29, 176, 12, 4, 14, 3, 6],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1, 29, 176, 12, 4, 14, 3, 6, 97],
#  [105, 173, 174, 175, 2, 78, 49, 15, 1, 29, 176, 12, 4, 14, 3, 6, 97, 177],
#  [105,
#   173,
#   174,
#   175,
#   2,
#   78,
#   49,
#   15,
#   1,
#   29,
#   176,
#   12,
#   4,
#   14,
#   3,
#   6,
#   97,
#   177,
#   178],
#  [105,
#   173,
#   174,
#   175,
#   2,
#   78,
#   49,
#   15,
#   1,
#   29,
#   176,
#   12,
#   4,
#   14,
#   3,
#   6,
#   97,
#   177,
#   178,
#   5],
#  [105,
#   173,
#   174,
#   175,
#   2,
#   78,
#   49,
#   15,
#   1,
#   29,
#   176,
#   12,
#   4,
#   14,
#   3,
#   6,
#   97,
#   177,
#   178,
#   5,
#   179],
#  [105,
#   173,
#   174,
#   175,
#   2,
#   78,
#   49,
#   15,
#   1,
#   29,
#   176,
#   12,
#   4,
#   14,
#   3,
#   6,
#   97,
#   177,
#   178,
#   5,
#   179,
#   72],
#  [105,
#   173,
#   174,
#   175,
#   2,
#   78,
#   49,
#   15,
#   1,
#   29,
#   176,
#   12,
#   4,
#   14,
#   3,
#   6,
#   97,
#   177,
#   178,
#   5,
#   179,
#   72,
#   106],
#  [105,
#   173,
#   174,
#   175,
#   2,
#   78,
#   49,
#   15,
#   1,
#   29,
#   176,
#   12,
#   4,
#   14,
#   3,
#   6,
#   97,
#   177,
#   178,
#   5,
#   179,
#   72,
#   106,
#   1],
#  [105,
#   173,
#   174,
#   175,
#   2,
#   78,
#   49,
#   15,
#   1,
#   29,
#   176,
#   12,
#   4,
#   14,
#   3,
#   6,
#   97,
#   177,
#   178,
#   5,
#   179,
#   72,
#   106,
#   1,
#   15],
#  [180, 3],
#  [180, 3, 6],
#  [180, 3, 6, 181],
#  [180, 3, 6, 181, 182],
#  [180, 3, 6, 181, 182, 16],
#  [180, 3, 6, 181, 182, 16, 23],
#  [180, 3, 6, 181, 182, 16, 23, 39],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42, 6],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42, 6, 183],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42, 6, 183, 8],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42, 6, 183, 8, 2],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42, 6, 183, 8, 2, 73],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42, 6, 183, 8, 2, 73, 7],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42, 6, 183, 8, 2, 73, 7, 50],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42, 6, 183, 8, 2, 73, 7, 50, 2],
#  [180, 3, 6, 181, 182, 16, 23, 39, 9, 30, 42, 6, 183, 8, 2, 73, 7, 50, 2, 30],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184,
#   5],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184,
#   5,
#   17],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184,
#   5,
#   17,
#   108],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184,
#   5,
#   17,
#   108,
#   3],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184,
#   5,
#   17,
#   108,
#   3,
#   14],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184,
#   5,
#   17,
#   108,
#   3,
#   14,
#   31],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184,
#   5,
#   17,
#   108,
#   3,
#   14,
#   31,
#   2],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184,
#   5,
#   17,
#   108,
#   3,
#   14,
#   31,
#   2,
#   185],
#  [180,
#   3,
#   6,
#   181,
#   182,
#   16,
#   23,
#   39,
#   9,
#   30,
#   42,
#   6,
#   183,
#   8,
#   2,
#   73,
#   7,
#   50,
#   2,
#   30,
#   42,
#   9,
#   107,
#   7,
#   184,
#   5,
#   17,
#   108,
#   3,
#   14,
#   31,
#   2,
#   185,
#   103],
#  [105, 73],
#  [105, 73, 186],
#  [105, 73, 186, 17],
#  [105, 73, 186, 17, 187],
#  [105, 73, 186, 17, 187, 109],
#  [105, 73, 186, 17, 187, 109, 5],
#  [105, 73, 186, 17, 187, 109, 5, 40],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72, 15],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72, 15, 43],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72, 15, 43, 51],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72, 15, 43, 51, 44],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72, 15, 43, 51, 44, 52],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72, 15, 43, 51, 44, 52, 79],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72, 15, 43, 51, 44, 52, 79, 53],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72, 15, 43, 51, 44, 52, 79, 53, 54],
#  [105, 73, 186, 17, 187, 109, 5, 40, 72, 15, 43, 51, 44, 52, 79, 53, 54, 1],
#  [105,
#   73,
#   186,
#   17,
#   187,
#   109,
#   5,
#   40,
#   72,
#   15,
#   43,
#   51,
#   44,
#   52,
#   79,
#   53,
#   54,
#   1,
#   74],
#  [105,
#   73,
#   186,
#   17,
#   187,
#   109,
#   5,
#   40,
#   72,
#   15,
#   43,
#   51,
#   44,
#   52,
#   79,
#   53,
#   54,
#   1,
#   74,
#   24],
#  [110, 111],
#  [110, 111, 11],
#  [110, 111, 11, 3],
#  [110, 111, 11, 3, 6],
#  [110, 111, 11, 3, 6, 112],
#  [110, 111, 11, 3, 6, 112, 188],
#  [110, 111, 11, 3, 6, 112, 188, 31],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189, 23],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189, 23, 20],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189, 23, 20, 9],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189, 23, 20, 9, 55],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189, 23, 20, 9, 55, 190],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189, 23, 20, 9, 55, 190, 20],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189, 23, 20, 9, 55, 190, 20, 56],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189, 23, 20, 9, 55, 190, 20, 56, 191],
#  [110, 111, 11, 3, 6, 112, 188, 31, 189, 23, 20, 9, 55, 190, 20, 56, 191, 38],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1,
#   114],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1,
#   114,
#   8],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1,
#   114,
#   8,
#   81],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1,
#   114,
#   8,
#   81,
#   10],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1,
#   114,
#   8,
#   81,
#   10,
#   76],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1,
#   114,
#   8,
#   81,
#   10,
#   76,
#   21],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1,
#   114,
#   8,
#   81,
#   10,
#   76,
#   21,
#   115],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1,
#   114,
#   8,
#   81,
#   10,
#   76,
#   21,
#   115,
#   2],
#  [110,
#   111,
#   11,
#   3,
#   6,
#   112,
#   188,
#   31,
#   189,
#   23,
#   20,
#   9,
#   55,
#   190,
#   20,
#   56,
#   191,
#   38,
#   113,
#   80,
#   57,
#   1,
#   114,
#   8,
#   81,
#   10,
#   76,
#   21,
#   115,
#   2,
#   3],
#  [5, 192],
#  [5, 192, 193],
#  [5, 192, 193, 194],
#  [5, 192, 193, 194, 32],
#  [5, 192, 193, 194, 32, 195],
#  [5, 192, 193, 194, 32, 195, 196],
#  [5, 192, 193, 194, 32, 195, 196, 45],
#  [5, 192, 193, 194, 32, 195, 196, 45, 33],
#  [5, 192, 193, 194, 32, 195, 196, 45, 33, 13],
#  [5, 192, 193, 194, 32, 195, 196, 45, 33, 13, 116],
#  [5, 192, 193, 194, 32, 195, 196, 45, 33, 13, 116, 1],
#  [5, 192, 193, 194, 32, 195, 196, 45, 33, 13, 116, 1, 58],
#  [5, 192, 193, 194, 32, 195, 196, 45, 33, 13, 116, 1, 58, 117],
#  [5, 192, 193, 194, 32, 195, 196, 45, 33, 13, 116, 1, 58, 117, 48],
#  [5, 192, 193, 194, 32, 195, 196, 45, 33, 13, 116, 1, 58, 117, 48, 118],
#  [5, 192, 193, 194, 32, 195, 196, 45, 33, 13, 116, 1, 58, 117, 48, 118, 197],
#  [5,
#   192,
#   193,
#   194,
#   32,
#   195,
#   196,
#   45,
#   33,
#   13,
#   116,
#   1,
#   58,
#   117,
#   48,
#   118,
#   197,
#   59],
#  [5,
#   192,
#   193,
#   194,
#   32,
#   195,
#   196,
#   45,
#   33,
#   13,
#   116,
#   1,
#   58,
#   117,
#   48,
#   118,
#   197,
#   59,
#   5],
#  [5,
#   192,
#   193,
#   194,
#   32,
#   195,
#   196,
#   45,
#   33,
#   13,
#   116,
#   1,
#   58,
#   117,
#   48,
#   118,
#   197,
#   59,
#   5,
#   3],
#  [5,
#   192,
#   193,
#   194,
#   32,
#   195,
#   196,
#   45,
#   33,
#   13,
#   116,
#   1,
#   58,
#   117,
#   48,
#   118,
#   197,
#   59,
#   5,
#   3,
#   6],
#  [5,
#   192,
#   193,
#   194,
#   32,
#   195,
#   196,
#   45,
#   33,
#   13,
#   116,
#   1,
#   58,
#   117,
#   48,
#   118,
#   197,
#   59,
#   5,
#   3,
#   6,
#   34],
#  [100, 60],
#  [100, 60, 117],
#  [100, 60, 117, 4],
#  [100, 60, 117, 4, 13],
#  [100, 60, 117, 4, 13, 48],
#  [100, 60, 117, 4, 13, 48, 198],
#  [100, 60, 117, 4, 13, 48, 198, 61],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119, 199],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119, 199, 8],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119, 199, 8, 58],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119, 199, 8, 58, 200],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119, 199, 8, 58, 200, 8],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119, 199, 8, 58, 200, 8, 201],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119, 199, 8, 58, 200, 8, 201, 2],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119, 199, 8, 58, 200, 8, 201, 2, 202],
#  [100, 60, 117, 4, 13, 48, 198, 61, 119, 199, 8, 58, 200, 8, 201, 2, 202, 120],
#  [100,
#   60,
#   117,
#   4,
#   13,
#   48,
#   198,
#   61,
#   119,
#   199,
#   8,
#   58,
#   200,
#   8,
#   201,
#   2,
#   202,
#   120,
#   203],
#  [100,
#   60,
#   117,
#   4,
#   13,
#   48,
#   198,
#   61,
#   119,
#   199,
#   8,
#   58,
#   200,
#   8,
#   201,
#   2,
#   202,
#   120,
#   203,
#   1],
#  [100,
#   60,
#   117,
#   4,
#   13,
#   48,
#   198,
#   61,
#   119,
#   199,
#   8,
#   58,
#   200,
#   8,
#   201,
#   2,
#   202,
#   120,
#   203,
#   1,
#   81],
#  [100,
#   60,
#   117,
#   4,
#   13,
#   48,
#   198,
#   61,
#   119,
#   199,
#   8,
#   58,
#   200,
#   8,
#   201,
#   2,
#   202,
#   120,
#   203,
#   1,
#   81,
#   10],
#  [100,
#   60,
#   117,
#   4,
#   13,
#   48,
#   198,
#   61,
#   119,
#   199,
#   8,
#   58,
#   200,
#   8,
#   201,
#   2,
#   202,
#   120,
#   203,
#   1,
#   81,
#   10,
#   19],
#  [100,
#   60,
#   117,
#   4,
#   13,
#   48,
#   198,
#   61,
#   119,
#   199,
#   8,
#   58,
#   200,
#   8,
#   201,
#   2,
#   202,
#   120,
#   203,
#   1,
#   81,
#   10,
#   19,
#   21],
#  [100,
#   60,
#   117,
#   4,
#   13,
#   48,
#   198,
#   61,
#   119,
#   199,
#   8,
#   58,
#   200,
#   8,
#   201,
#   2,
#   202,
#   120,
#   203,
#   1,
#   81,
#   10,
#   19,
#   21,
#   5],
#  [100,
#   60,
#   117,
#   4,
#   13,
#   48,
#   198,
#   61,
#   119,
#   199,
#   8,
#   58,
#   200,
#   8,
#   201,
#   2,
#   202,
#   120,
#   203,
#   1,
#   81,
#   10,
#   19,
#   21,
#   5,
#   121],
#  [100,
#   60,
#   117,
#   4,
#   13,
#   48,
#   198,
#   61,
#   119,
#   199,
#   8,
#   58,
#   200,
#   8,
#   201,
#   2,
#   202,
#   120,
#   203,
#   1,
#   81,
#   10,
#   19,
#   21,
#   5,
#   121,
#   25],
#  [4, 13],
#  [4, 13, 12],
#  [4, 13, 12, 58],
#  [4, 13, 12, 58, 122],
#  [4, 13, 12, 58, 122, 62],
#  [4, 13, 12, 58, 122, 62, 204],
#  [4, 13, 12, 58, 122, 62, 204, 82],
#  [4, 13, 12, 58, 122, 62, 204, 82, 205],
#  [4, 13, 12, 58, 122, 62, 204, 82, 205, 206],
#  [4, 13, 12, 58, 122, 62, 204, 82, 205, 206, 11],
#  [4, 13, 12, 58, 122, 62, 204, 82, 205, 206, 11, 39],
#  [4, 13, 12, 58, 122, 62, 204, 82, 205, 206, 11, 39, 121],
#  [4, 13, 12, 58, 122, 62, 204, 82, 205, 206, 11, 39, 121, 25],
#  [4, 13, 12, 58, 122, 62, 204, 82, 205, 206, 11, 39, 121, 25, 12],
#  [4, 13, 12, 58, 122, 62, 204, 82, 205, 206, 11, 39, 121, 25, 12, 207],
#  [4, 13, 12, 58, 122, 62, 204, 82, 205, 206, 11, 39, 121, 25, 12, 207, 208],
#  [4,
#   13,
#   12,
#   58,
#   122,
#   62,
#   204,
#   82,
#   205,
#   206,
#   11,
#   39,
#   121,
#   25,
#   12,
#   207,
#   208,
#   209],
#  [4,
#   13,
#   12,
#   58,
#   122,
#   62,
#   204,
#   82,
#   205,
#   206,
#   11,
#   39,
#   121,
#   25,
#   12,
#   207,
#   208,
#   209,
#   63],
#  [4,
#   13,
#   12,
#   58,
#   122,
#   62,
#   204,
#   82,
#   205,
#   206,
#   11,
#   39,
#   121,
#   25,
#   12,
#   207,
#   208,
#   209,
#   63,
#   123],
#  [4,
#   13,
#   12,
#   58,
#   122,
#   62,
#   204,
#   82,
#   205,
#   206,
#   11,
#   39,
#   121,
#   25,
#   12,
#   207,
#   208,
#   209,
#   63,
#   123,
#   124],
#  [4,
#   13,
#   12,
#   58,
#   122,
#   62,
#   204,
#   82,
#   205,
#   206,
#   11,
#   39,
#   121,
#   25,
#   12,
#   207,
#   208,
#   209,
#   63,
#   123,
#   124,
#   125],
#  [4,
#   13,
#   12,
#   58,
#   122,
#   62,
#   204,
#   82,
#   205,
#   206,
#   11,
#   39,
#   121,
#   25,
#   12,
#   207,
#   208,
#   209,
#   63,
#   123,
#   124,
#   125,
#   11],
#  [4,
#   13,
#   12,
#   58,
#   122,
#   62,
#   204,
#   82,
#   205,
#   206,
#   11,
#   39,
#   121,
#   25,
#   12,
#   207,
#   208,
#   209,
#   63,
#   123,
#   124,
#   125,
#   11,
#   3],
#  [4,
#   13,
#   12,
#   58,
#   122,
#   62,
#   204,
#   82,
#   205,
#   206,
#   11,
#   39,
#   121,
#   25,
#   12,
#   207,
#   208,
#   209,
#   63,
#   123,
#   124,
#   125,
#   11,
#   3,
#   6],
#  [4,
#   13,
#   12,
#   58,
#   122,
#   62,
#   204,
#   82,
#   205,
#   206,
#   11,
#   39,
#   121,
#   25,
#   12,
#   207,
#   208,
#   209,
#   63,
#   123,
#   124,
#   125,
#   11,
#   3,
#   6,
#   34],
#  [78, 7],
#  [78, 7, 4],
#  [78, 7, 4, 4],
#  [78, 7, 4, 4, 13],
#  [78, 7, 4, 4, 13, 26],
#  [78, 7, 4, 4, 13, 26, 17],
#  [78, 7, 4, 4, 13, 26, 17, 210],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45, 33],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45, 33, 64],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45, 33, 64, 62],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45, 33, 64, 62, 211],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45, 33, 64, 62, 211, 8],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45, 33, 64, 62, 211, 8, 212],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45, 33, 64, 62, 211, 8, 212, 2],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45, 33, 64, 62, 211, 8, 212, 2, 213],
#  [78, 7, 4, 4, 13, 26, 17, 210, 7, 45, 33, 64, 62, 211, 8, 212, 2, 213, 7],
#  [78,
#   7,
#   4,
#   4,
#   13,
#   26,
#   17,
#   210,
#   7,
#   45,
#   33,
#   64,
#   62,
#   211,
#   8,
#   212,
#   2,
#   213,
#   7,
#   110],
#  [78,
#   7,
#   4,
#   4,
#   13,
#   26,
#   17,
#   210,
#   7,
#   45,
#   33,
#   64,
#   62,
#   211,
#   8,
#   212,
#   2,
#   213,
#   7,
#   110,
#   116],
#  [78,
#   7,
#   4,
#   4,
#   13,
#   26,
#   17,
#   210,
#   7,
#   45,
#   33,
#   64,
#   62,
#   211,
#   8,
#   212,
#   2,
#   213,
#   7,
#   110,
#   116,
#   5],
#  [78,
#   7,
#   4,
#   4,
#   13,
#   26,
#   17,
#   210,
#   7,
#   45,
#   33,
#   64,
#   62,
#   211,
#   8,
#   212,
#   2,
#   213,
#   7,
#   110,
#   116,
#   5,
#   75],
#  [78,
#   7,
#   4,
#   4,
#   13,
#   26,
#   17,
#   210,
#   7,
#   45,
#   33,
#   64,
#   62,
#   211,
#   8,
#   212,
#   2,
#   213,
#   7,
#   110,
#   116,
#   5,
#   75,
#   10],
#  [78,
#   7,
#   4,
#   4,
#   13,
#   26,
#   17,
#   210,
#   7,
#   45,
#   33,
#   64,
#   62,
#   211,
#   8,
#   212,
#   2,
#   213,
#   7,
#   110,
#   116,
#   5,
#   75,
#   10,
#   76],
#  [78,
#   7,
#   4,
#   4,
#   13,
#   26,
#   17,
#   210,
#   7,
#   45,
#   33,
#   64,
#   62,
#   211,
#   8,
#   212,
#   2,
#   213,
#   7,
#   110,
#   116,
#   5,
#   75,
#   10,
#   76,
#   21],
#  [83, 2],
#  [83, 2, 214],
#  [83, 2, 214, 7],
#  [83, 2, 214, 7, 4],
#  [83, 2, 214, 7, 4, 13],
#  [83, 2, 214, 7, 4, 13, 26],
#  [83, 2, 214, 7, 4, 13, 26, 28],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216, 12],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216, 12, 40],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216, 12, 40, 35],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216, 12, 40, 35, 43],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216, 12, 40, 35, 43, 65],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216, 12, 40, 35, 43, 65, 35],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216, 12, 40, 35, 43, 65, 35, 126],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216, 12, 40, 35, 43, 65, 35, 126, 35],
#  [83, 2, 214, 7, 4, 13, 26, 28, 215, 216, 12, 40, 35, 43, 65, 35, 126, 35, 1],
#  [83,
#   2,
#   214,
#   7,
#   4,
#   13,
#   26,
#   28,
#   215,
#   216,
#   12,
#   40,
#   35,
#   43,
#   65,
#   35,
#   126,
#   35,
#   1,
#   84],
#  [83,
#   2,
#   214,
#   7,
#   4,
#   13,
#   26,
#   28,
#   215,
#   216,
#   12,
#   40,
#   35,
#   43,
#   65,
#   35,
#   126,
#   35,
#   1,
#   84,
#   35],
#  [60, 35],
#  [60, 35, 217],
#  [60, 35, 217, 2],
#  [60, 35, 217, 2, 218],
#  [60, 35, 217, 2, 218, 7],
#  [60, 35, 217, 2, 218, 7, 18],
#  [60, 35, 217, 2, 218, 7, 18, 115],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2, 64],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2, 64, 219],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2, 64, 219, 127],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2, 64, 219, 127, 8],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2, 64, 219, 127, 8, 128],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2, 64, 219, 127, 8, 128, 129],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2, 64, 219, 127, 8, 128, 129, 18],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2, 64, 219, 127, 8, 128, 129, 18, 77],
#  [60, 35, 217, 2, 218, 7, 18, 115, 2, 64, 219, 127, 8, 128, 129, 18, 77, 10],
#  [60,
#   35,
#   217,
#   2,
#   218,
#   7,
#   18,
#   115,
#   2,
#   64,
#   219,
#   127,
#   8,
#   128,
#   129,
#   18,
#   77,
#   10,
#   41],
#  [60,
#   35,
#   217,
#   2,
#   218,
#   7,
#   18,
#   115,
#   2,
#   64,
#   219,
#   127,
#   8,
#   128,
#   129,
#   18,
#   77,
#   10,
#   41,
#   130],
#  [60,
#   35,
#   217,
#   2,
#   218,
#   7,
#   18,
#   115,
#   2,
#   64,
#   219,
#   127,
#   8,
#   128,
#   129,
#   18,
#   77,
#   10,
#   41,
#   130,
#   220],
#  [60,
#   35,
#   217,
#   2,
#   218,
#   7,
#   18,
#   115,
#   2,
#   64,
#   219,
#   127,
#   8,
#   128,
#   129,
#   18,
#   77,
#   10,
#   41,
#   130,
#   220,
#   131],
#  [60,
#   35,
#   217,
#   2,
#   218,
#   7,
#   18,
#   115,
#   2,
#   64,
#   219,
#   127,
#   8,
#   128,
#   129,
#   18,
#   77,
#   10,
#   41,
#   130,
#   220,
#   131,
#   221],
#  [60,
#   35,
#   217,
#   2,
#   218,
#   7,
#   18,
#   115,
#   2,
#   64,
#   219,
#   127,
#   8,
#   128,
#   129,
#   18,
#   77,
#   10,
#   41,
#   130,
#   220,
#   131,
#   221,
#   18],
#  [2, 132],
#  [2, 132, 222],
#  [2, 132, 222, 7],
#  [2, 132, 222, 7, 82],
#  [2, 132, 222, 7, 82, 4],
#  [2, 132, 222, 7, 82, 4, 46],
#  [2, 132, 222, 7, 82, 4, 46, 133],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85, 86],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85, 86, 56],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85, 86, 56, 18],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85, 86, 56, 18, 38],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85, 86, 56, 18, 38, 2],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85, 86, 56, 18, 38, 2, 223],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85, 86, 56, 18, 38, 2, 223, 46],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85, 86, 56, 18, 38, 2, 223, 46, 47],
#  [2, 132, 222, 7, 82, 4, 46, 133, 126, 85, 86, 56, 18, 38, 2, 223, 46, 47, 87],
#  [2,
#   132,
#   222,
#   7,
#   82,
#   4,
#   46,
#   133,
#   126,
#   85,
#   86,
#   56,
#   18,
#   38,
#   2,
#   223,
#   46,
#   47,
#   87,
#   66],
#  [2,
#   132,
#   222,
#   7,
#   82,
#   4,
#   46,
#   133,
#   126,
#   85,
#   86,
#   56,
#   18,
#   38,
#   2,
#   223,
#   46,
#   47,
#   87,
#   66,
#   224],
#  [2,
#   132,
#   222,
#   7,
#   82,
#   4,
#   46,
#   133,
#   126,
#   85,
#   86,
#   56,
#   18,
#   38,
#   2,
#   223,
#   46,
#   47,
#   87,
#   66,
#   224,
#   9],
#  [2,
#   132,
#   222,
#   7,
#   82,
#   4,
#   46,
#   133,
#   126,
#   85,
#   86,
#   56,
#   18,
#   38,
#   2,
#   223,
#   46,
#   47,
#   87,
#   66,
#   224,
#   9,
#   225],
#  [65, 85],
#  [65, 85, 86],
#  [65, 85, 86, 56],
#  [65, 85, 86, 56, 226],
#  [65, 85, 86, 56, 226, 18],
#  [65, 85, 86, 56, 226, 18, 38],
#  [65, 85, 86, 56, 226, 18, 38, 2],
#  [65, 85, 86, 56, 226, 18, 38, 2, 134],
#  [65, 85, 86, 56, 226, 18, 38, 2, 134, 65],
#  [65, 85, 86, 56, 226, 18, 38, 2, 134, 65, 87],
#  [65, 85, 86, 56, 226, 18, 38, 2, 134, 65, 87, 66],
#  [65, 85, 86, 56, 226, 18, 38, 2, 134, 65, 87, 66, 227],
#  [65, 85, 86, 56, 226, 18, 38, 2, 134, 65, 87, 66, 227, 5],
#  [65, 85, 86, 56, 226, 18, 38, 2, 134, 65, 87, 66, 227, 5, 2],
#  [65, 85, 86, 56, 226, 18, 38, 2, 134, 65, 87, 66, 227, 5, 2, 46],
#  [65, 85, 86, 56, 226, 18, 38, 2, 134, 65, 87, 66, 227, 5, 2, 46, 47],
#  [46, 47],
#  [46, 47, 135],
#  [46, 47, 135, 2],
#  [46, 47, 135, 2, 10],
#  [46, 47, 135, 2, 10, 19],
#  [46, 47, 135, 2, 10, 19, 28],
#  [46, 47, 135, 2, 10, 19, 28, 7],
#  [46, 47, 135, 2, 10, 19, 28, 7, 2],
#  [46, 47, 135, 2, 10, 19, 28, 7, 2, 64],
#  [46, 47, 135, 2, 10, 19, 28, 7, 2, 64, 102],
#  [46, 47, 135, 2, 10, 19, 28, 7, 2, 64, 102, 18],
#  [46, 47, 135, 2, 10, 19, 28, 7, 2, 64, 102, 18, 88],
#  [46, 47, 135, 2, 10, 19, 28, 7, 2, 64, 102, 18, 88, 67],
#  [46, 47, 135, 2, 10, 19, 28, 7, 2, 64, 102, 18, 88, 67, 228],
#  [84, 85],
#  [84, 85, 86],
#  [84, 85, 86, 56],
#  [84, 85, 86, 56, 18],
#  [84, 85, 86, 56, 18, 38],
#  [84, 85, 86, 56, 18, 38, 2],
#  [84, 85, 86, 56, 18, 38, 2, 134],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46, 47],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46, 47, 87],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46, 47, 87, 66],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46, 47, 87, 66, 84],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46, 47, 87, 66, 84, 8],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46, 47, 87, 66, 84, 8, 2],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46, 47, 87, 66, 84, 8, 2, 30],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46, 47, 87, 66, 84, 8, 2, 30, 67],
#  [84, 85, 86, 56, 18, 38, 2, 134, 46, 47, 87, 66, 84, 8, 2, 30, 67, 229],
#  [89, 32],
#  [89, 32, 8],
#  [89, 32, 8, 230],
#  [89, 32, 8, 230, 231],
#  [89, 32, 8, 230, 231, 1],
#  [89, 32, 8, 230, 231, 1, 232],
#  [89, 32, 8, 230, 231, 1, 232, 18],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2, 35],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2, 35, 4],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2, 35, 4, 13],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2, 35, 4, 13, 90],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2, 35, 4, 13, 90, 233],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2, 35, 4, 13, 90, 233, 81],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2, 35, 4, 13, 90, 233, 81, 10],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2, 35, 4, 13, 90, 233, 81, 10, 19],
#  [89, 32, 8, 230, 231, 1, 232, 18, 136, 2, 35, 4, 13, 90, 233, 81, 10, 19, 21],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104,
#   41],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104,
#   41,
#   63],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104,
#   41,
#   63,
#   123],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104,
#   41,
#   63,
#   123,
#   124],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104,
#   41,
#   63,
#   123,
#   124,
#   125],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104,
#   41,
#   63,
#   123,
#   124,
#   125,
#   11],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104,
#   41,
#   63,
#   123,
#   124,
#   125,
#   11,
#   3],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104,
#   41,
#   63,
#   123,
#   124,
#   125,
#   11,
#   3,
#   6],
#  [89,
#   32,
#   8,
#   230,
#   231,
#   1,
#   232,
#   18,
#   136,
#   2,
#   35,
#   4,
#   13,
#   90,
#   233,
#   81,
#   10,
#   19,
#   21,
#   1,
#   128,
#   80,
#   18,
#   77,
#   104,
#   41,
#   63,
#   123,
#   124,
#   125,
#   11,
#   3,
#   6,
#   34],
#  [49, 11],
#  [49, 11, 4],
#  [49, 11, 4, 14],
#  [49, 11, 4, 14, 3],
#  [49, 11, 4, 14, 3, 6],
#  [49, 11, 4, 14, 3, 6, 4],
#  [49, 11, 4, 14, 3, 6, 4, 14],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6, 234],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6, 234, 137],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6, 234, 137, 132],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6, 234, 137, 132, 49],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6, 234, 137, 132, 49, 1],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6, 234, 137, 132, 49, 1, 22],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6, 234, 137, 132, 49, 1, 22, 235],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6, 234, 137, 132, 49, 1, 22, 235, 83],
#  [49, 11, 4, 14, 3, 6, 4, 14, 3, 6, 234, 137, 132, 49, 1, 22, 235, 83, 68],
#  [49,
#   11,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   234,
#   137,
#   132,
#   49,
#   1,
#   22,
#   235,
#   83,
#   68,
#   236],
#  [49,
#   11,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   234,
#   137,
#   132,
#   49,
#   1,
#   22,
#   235,
#   83,
#   68,
#   236,
#   1],
#  [49,
#   11,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   234,
#   137,
#   132,
#   49,
#   1,
#   22,
#   235,
#   83,
#   68,
#   236,
#   1,
#   138],
#  [49,
#   11,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   234,
#   137,
#   132,
#   49,
#   1,
#   22,
#   235,
#   83,
#   68,
#   236,
#   1,
#   138,
#   99],
#  [49,
#   11,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   234,
#   137,
#   132,
#   49,
#   1,
#   22,
#   235,
#   83,
#   68,
#   236,
#   1,
#   138,
#   99,
#   20],
#  [60, 49],
#  [60, 49, 133],
#  [60, 49, 133, 25],
#  [60, 49, 133, 25, 237],
#  [60, 49, 133, 25, 237, 238],
#  [60, 49, 133, 25, 237, 238, 1],
#  [60, 49, 133, 25, 237, 238, 1, 139],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7, 3],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7, 3, 25],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7, 3, 25, 43],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7, 3, 25, 43, 3],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7, 3, 25, 43, 3, 239],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7, 3, 25, 43, 3, 239, 139],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7, 3, 25, 43, 3, 239, 139, 1],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7, 3, 25, 43, 3, 239, 139, 1, 107],
#  [60, 49, 133, 25, 237, 238, 1, 139, 7, 3, 25, 43, 3, 239, 139, 1, 107, 240],
#  [36, 62],
#  [36, 62, 241],
#  [36, 62, 241, 2],
#  [36, 62, 241, 2, 62],
#  [36, 62, 241, 2, 62, 7],
#  [36, 62, 241, 2, 62, 7, 2],
#  [36, 62, 241, 2, 62, 7, 2, 4],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43, 2],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43, 2, 242],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43, 2, 242, 7],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43, 2, 242, 7, 243],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43, 2, 242, 7, 243, 244],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43, 2, 242, 7, 243, 244, 245],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43, 2, 242, 7, 243, 244, 245, 1],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43, 2, 242, 7, 243, 244, 245, 1, 246],
#  [36, 62, 241, 2, 62, 7, 2, 4, 64, 43, 2, 242, 7, 243, 244, 245, 1, 246, 247],
#  [68, 248],
#  [68, 248, 68],
#  [68, 248, 68, 2],
#  [68, 248, 68, 2, 4],
#  [68, 248, 68, 2, 4, 36],
#  [68, 248, 68, 2, 4, 36, 91],
#  [68, 248, 68, 2, 4, 36, 91, 249],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136, 67],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136, 67, 140],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136, 67, 140, 9],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136, 67, 140, 9, 250],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136, 67, 140, 9, 250, 140],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136, 67, 140, 9, 250, 140, 12],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136, 67, 140, 9, 250, 140, 12, 141],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136, 67, 140, 9, 250, 140, 12, 141, 22],
#  [68, 248, 68, 2, 4, 36, 91, 249, 136, 67, 140, 9, 250, 140, 12, 141, 22, 27],
#  [68,
#   248,
#   68,
#   2,
#   4,
#   36,
#   91,
#   249,
#   136,
#   67,
#   140,
#   9,
#   250,
#   140,
#   12,
#   141,
#   22,
#   27,
#   16],
#  [68,
#   248,
#   68,
#   2,
#   4,
#   36,
#   91,
#   249,
#   136,
#   67,
#   140,
#   9,
#   250,
#   140,
#   12,
#   141,
#   22,
#   27,
#   16,
#   251],
#  [68,
#   248,
#   68,
#   2,
#   4,
#   36,
#   91,
#   249,
#   136,
#   67,
#   140,
#   9,
#   250,
#   140,
#   12,
#   141,
#   22,
#   27,
#   16,
#   251,
#   120],
#  [68,
#   248,
#   68,
#   2,
#   4,
#   36,
#   91,
#   249,
#   136,
#   67,
#   140,
#   9,
#   250,
#   140,
#   12,
#   141,
#   22,
#   27,
#   16,
#   251,
#   120,
#   252],
#  [68,
#   248,
#   68,
#   2,
#   4,
#   36,
#   91,
#   249,
#   136,
#   67,
#   140,
#   9,
#   250,
#   140,
#   12,
#   141,
#   22,
#   27,
#   16,
#   251,
#   120,
#   252,
#   253],
#  [68,
#   248,
#   68,
#   2,
#   4,
#   36,
#   91,
#   249,
#   136,
#   67,
#   140,
#   9,
#   250,
#   140,
#   12,
#   141,
#   22,
#   27,
#   16,
#   251,
#   120,
#   252,
#   253,
#   9],
#  [68,
#   248,
#   68,
#   2,
#   4,
#   36,
#   91,
#   249,
#   136,
#   67,
#   140,
#   9,
#   250,
#   140,
#   12,
#   141,
#   22,
#   27,
#   16,
#   251,
#   120,
#   252,
#   253,
#   9,
#   254],
#  [255, 92],
#  [255, 92, 256],
#  [255, 92, 256, 257],
#  [255, 92, 256, 257, 27],
#  [255, 92, 256, 257, 27, 16],
#  [255, 92, 256, 257, 27, 16, 32],
#  [255, 92, 256, 257, 27, 16, 32, 142],
#  [255, 92, 256, 257, 27, 16, 32, 142, 143],
#  [255, 92, 256, 257, 27, 16, 32, 142, 143, 142],
#  [255, 92, 256, 257, 27, 16, 32, 142, 143, 142, 1],
#  [255, 92, 256, 257, 27, 16, 32, 142, 143, 142, 1, 258],
#  [255, 92, 256, 257, 27, 16, 32, 142, 143, 142, 1, 258, 259],
#  [255, 92, 256, 257, 27, 16, 32, 142, 143, 142, 1, 258, 259, 8],
#  [255, 92, 256, 257, 27, 16, 32, 142, 143, 142, 1, 258, 259, 8, 144],
#  [255, 92, 256, 257, 27, 16, 32, 142, 143, 142, 1, 258, 259, 8, 144, 36],
#  [255, 92, 256, 257, 27, 16, 32, 142, 143, 142, 1, 258, 259, 8, 144, 36, 59],
#  [145, 146],
#  [145, 146, 260],
#  [145, 146, 260, 36],
#  [145, 146, 260, 36, 59],
#  [145, 146, 260, 36, 59, 91],
#  [145, 146, 260, 36, 59, 91, 145],
#  [145, 146, 260, 36, 59, 91, 145, 146],
#  [145, 146, 260, 36, 59, 91, 145, 146, 27],
#  [145, 146, 260, 36, 59, 91, 145, 146, 27, 16],
#  [145, 146, 260, 36, 59, 91, 145, 146, 27, 16, 261],
#  [145, 146, 260, 36, 59, 91, 145, 146, 27, 16, 261, 262],
#  [145, 146, 260, 36, 59, 91, 145, 146, 27, 16, 261, 262, 263],
#  [145, 146, 260, 36, 59, 91, 145, 146, 27, 16, 261, 262, 263, 147],
#  [145, 146, 260, 36, 59, 91, 145, 146, 27, 16, 261, 262, 263, 147, 1],
#  [145, 146, 260, 36, 59, 91, 145, 146, 27, 16, 261, 262, 263, 147, 1, 148],
#  [145, 146, 260, 36, 59, 91, 145, 146, 27, 16, 261, 262, 263, 147, 1, 148, 31],
#  [145,
#   146,
#   260,
#   36,
#   59,
#   91,
#   145,
#   146,
#   27,
#   16,
#   261,
#   262,
#   263,
#   147,
#   1,
#   148,
#   31,
#   264],
#  [145,
#   146,
#   260,
#   36,
#   59,
#   91,
#   145,
#   146,
#   27,
#   16,
#   261,
#   262,
#   263,
#   147,
#   1,
#   148,
#   31,
#   264,
#   131],
#  [145,
#   146,
#   260,
#   36,
#   59,
#   91,
#   145,
#   146,
#   27,
#   16,
#   261,
#   262,
#   263,
#   147,
#   1,
#   148,
#   31,
#   264,
#   131,
#   265],
#  [145,
#   146,
#   260,
#   36,
#   59,
#   91,
#   145,
#   146,
#   27,
#   16,
#   261,
#   262,
#   263,
#   147,
#   1,
#   148,
#   31,
#   264,
#   131,
#   265,
#   9],
#  [145,
#   146,
#   260,
#   36,
#   59,
#   91,
#   145,
#   146,
#   27,
#   16,
#   261,
#   262,
#   263,
#   147,
#   1,
#   148,
#   31,
#   264,
#   131,
#   265,
#   9,
#   266],
#  [145,
#   146,
#   260,
#   36,
#   59,
#   91,
#   145,
#   146,
#   27,
#   16,
#   261,
#   262,
#   263,
#   147,
#   1,
#   148,
#   31,
#   264,
#   131,
#   265,
#   9,
#   266,
#   267],
#  [149, 92],
#  [149, 92, 1],
#  [149, 92, 1, 150],
#  [149, 92, 1, 150, 32],
#  [149, 92, 1, 150, 32, 149],
#  [149, 92, 1, 150, 32, 149, 92],
#  [149, 92, 1, 150, 32, 149, 92, 151],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93, 4],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93, 4, 20],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93, 4, 20, 31],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93, 4, 20, 31, 268],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93, 4, 20, 31, 268, 269],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93, 4, 20, 31, 268, 269, 25],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93, 4, 20, 31, 268, 269, 25, 9],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93, 4, 20, 31, 268, 269, 25, 9, 91],
#  [149, 92, 1, 150, 32, 149, 92, 151, 93, 4, 20, 31, 268, 269, 25, 9, 91, 150],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8,
#   270],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8,
#   270,
#   151],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8,
#   270,
#   151,
#   93],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8,
#   270,
#   151,
#   93,
#   23],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8,
#   270,
#   151,
#   93,
#   23,
#   20],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8,
#   270,
#   151,
#   93,
#   23,
#   20,
#   11],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8,
#   270,
#   151,
#   93,
#   23,
#   20,
#   11,
#   3],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8,
#   270,
#   151,
#   93,
#   23,
#   20,
#   11,
#   3,
#   6],
#  [149,
#   92,
#   1,
#   150,
#   32,
#   149,
#   92,
#   151,
#   93,
#   4,
#   20,
#   31,
#   268,
#   269,
#   25,
#   9,
#   91,
#   150,
#   32,
#   22,
#   8,
#   270,
#   151,
#   93,
#   23,
#   20,
#   11,
#   3,
#   6,
#   34],
#  [15, 7],
#  [15, 7, 4],
#  [15, 7, 4, 14],
#  [15, 7, 4, 14, 3],
#  [15, 7, 4, 14, 3, 6],
#  [15, 7, 4, 14, 3, 6, 4],
#  [15, 7, 4, 14, 3, 6, 4, 14],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271, 15],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271, 15, 88],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271, 15, 88, 40],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271, 15, 88, 40, 152],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271, 15, 88, 40, 152, 1],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271, 15, 88, 40, 152, 1, 272],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271, 15, 88, 40, 152, 1, 272, 43],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271, 15, 88, 40, 152, 1, 272, 43, 74],
#  [15, 7, 4, 14, 3, 6, 4, 14, 3, 6, 271, 15, 88, 40, 152, 1, 272, 43, 74, 24],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278,
#   279],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278,
#   279,
#   5],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278,
#   279,
#   5,
#   280],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278,
#   279,
#   5,
#   280,
#   281],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278,
#   279,
#   5,
#   280,
#   281,
#   282],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278,
#   279,
#   5,
#   280,
#   281,
#   282,
#   283],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278,
#   279,
#   5,
#   280,
#   281,
#   282,
#   283,
#   1],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278,
#   279,
#   5,
#   280,
#   281,
#   282,
#   283,
#   1,
#   284],
#  [15,
#   7,
#   4,
#   14,
#   3,
#   6,
#   4,
#   14,
#   3,
#   6,
#   271,
#   15,
#   88,
#   40,
#   152,
#   1,
#   272,
#   43,
#   74,
#   24,
#   273,
#   274,
#   67,
#   275,
#   11,
#   2,
#   30,
#   42,
#   9,
#   153,
#   5,
#   3,
#   65,
#   276,
#   277,
#   278,
#   279,
#   5,
#   280,
#   281,
#   282,
#   283,
#   1,
#   284,
#   285],
#  [52, 79],
#  [52, 79, 50],
#  [52, 79, 50, 2],
#  [52, 79, 50, 2, 30],
#  [52, 79, 50, 2, 30, 42],
#  [52, 79, 50, 2, 30, 42, 9],
#  [52, 79, 50, 2, 30, 42, 9, 286],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52, 79],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52, 79, 24],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52, 79, 24, 287],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52, 79, 24, 287, 288],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52, 79, 24, 287, 288, 148],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52, 79, 24, 287, 288, 148, 1],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52, 79, 24, 287, 288, 148, 1, 289],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52, 79, 24, 287, 288, 148, 1, 289, 5],
#  [52, 79, 50, 2, 30, 42, 9, 286, 5, 52, 79, 24, 287, 288, 148, 1, 289, 5, 52],
#  [52,
#   79,
#   50,
#   2,
#   30,
#   42,
#   9,
#   286,
#   5,
#   52,
#   79,
#   24,
#   287,
#   288,
#   148,
#   1,
#   289,
#   5,
#   52,
#   8],
#  [52,
#   79,
#   50,
#   2,
#   30,
#   42,
#   9,
#   286,
#   5,
#   52,
#   79,
#   24,
#   287,
#   288,
#   148,
#   1,
#   289,
#   5,
#   52,
#   8,
#   3],
#  [52,
#   79,
#   50,
#   2,
#   30,
#   42,
#   9,
#   286,
#   5,
#   52,
#   79,
#   24,
#   287,
#   288,
#   148,
#   1,
#   289,
#   5,
#   52,
#   8,
#   3,
#   15],
#  [23, 39],
#  [23, 39, 94],
#  [23, 39, 94, 290],
#  [23, 39, 94, 290, 1],
#  [23, 39, 94, 290, 1, 291],
#  [23, 39, 94, 290, 1, 291, 129],
#  [23, 39, 94, 290, 1, 291, 129, 3],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14, 31],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14, 31, 17],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14, 31, 17, 108],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14, 31, 17, 108, 292],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14, 31, 17, 108, 292, 9],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14, 31, 17, 108, 292, 9, 293],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14, 31, 17, 108, 292, 9, 293, 3],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14, 31, 17, 108, 292, 9, 293, 3, 294],
#  [23, 39, 94, 290, 1, 291, 129, 3, 14, 31, 17, 108, 292, 9, 293, 3, 294, 15],
#  [23,
#   39,
#   94,
#   290,
#   1,
#   291,
#   129,
#   3,
#   14,
#   31,
#   17,
#   108,
#   292,
#   9,
#   293,
#   3,
#   294,
#   15,
#   27],
#  [23,
#   39,
#   94,
#   290,
#   1,
#   291,
#   129,
#   3,
#   14,
#   31,
#   17,
#   108,
#   292,
#   9,
#   293,
#   3,
#   294,
#   15,
#   27,
#   16],
#  [23,
#   39,
#   94,
#   290,
#   1,
#   291,
#   129,
#   3,
#   14,
#   31,
#   17,
#   108,
#   292,
#   9,
#   293,
#   3,
#   294,
#   15,
#   27,
#   16,
#   295],
#  [23,
#   39,
#   94,
#   290,
#   1,
#   291,
#   129,
#   3,
#   14,
#   31,
#   17,
#   108,
#   292,
#   9,
#   293,
#   3,
#   294,
#   15,
#   27,
#   16,
#   295,
#   296],
#  [23,
#   39,
#   94,
#   290,
#   1,
# ...
#   317,
#   2,
#   61,
#   318,
#   1,
#   319,
#   320,
#   12,
#   4,
#   14,
#   3,
#   6,
#   137,
#   29,
#   1,
#   321,
#   11,
#   322,
#   323,
#   156,
#   10,
#   19,
#   21,
#   130,
#   4,
#   13,
#   324,
#   83,
#   75,
#   10,
#   19,
#   21,
#   325,
#   326,
#   327,
#   114,
#   12,
#   328,
#   10,
#   41,
#   9,
#   329,
#   330],
#  [29,
#   1,
#   155,
#   316,
#   317,
#   2,
#   61,
#   318,
#   1,
#   319,
#   320,
#   12,
#   4,
#   14,
#   3,
#   6,
#   137,
#   29,
#   1,
#   321,
#   11,
#   322,
#   323,
#   156,
#   10,
#   19,
#   21,
#   130,
#   4,
#   13,
#   324,
#   83,
#   75,
#   10,
#   19,
#   21,
#   325,
#   326,
#   327,
#   114,
#   12,
#   328,
#   10,
#   41,
#   9,
#   329,
#   330,
#   8],
#  [29,
#   1,
#   155,
#   316,
#   317,
#   2,
#   61,
#   318,
#   1,
#   319,
#   320,
#   12,
#   4,
#   14,
#   3,
#   6,
#   137,
#   29,
#   1,
#   321,
#   11,
#   322,
#   323,
#   156,
#   10,
#   19,
#   21,
#   130,
#   4,
#   13,
#   324,
#   83,
#   75,
#   10,
#   19,
#   21,
#   325,
#   326,
#   327,
#   114,
#   12,
#   328,
#   10,
#   41,
#   9,
#   329,
#   330,
#   8,
#   18],
#  [29,
#   1,
#   155,
#   316,
#   317,
#   2,
#   61,
#   318,
#   1,
#   319,
#   320,
#   12,
#   4,
#   14,
#   3,
#   6,
#   137,
#   29,
#   1,
#   321,
#   11,
#   322,
#   323,
#   156,
#   10,
#   19,
#   21,
#   130,
#   4,
#   13,
#   324,
#   83,
#   75,
#   10,
#   19,
#   21,
#   325,
#   326,
#   327,
#   114,
#   12,
#   328,
#   10,
#   41,
#   9,
#   329,
#   330,
#   8,
#   18,
#   147],
#  [29,
#   1,
#   155,
#   316,
#   317,
#   2,
#   61,
#   318,
#   1,
#   319,
#   320,
#   12,
#   4,
#   14,
#   3,
#   6,
#   137,
#   29,
#   1,
#   321,
#   11,
#   322,
#   323,
#   156,
#   10,
#   19,
#   21,
#   130,
#   4,
#   13,
#   324,
#   83,
#   75,
#   10,
#   19,
#   21,
#   325,
#   326,
#   327,
#   114,
#   12,
#   328,
#   10,
#   41,
#   9,
#   329,
#   330,
#   8,
#   18,
#   147,
#   9],
#  [29,
#   1,
#   155,
#   316,
#   317,
#   2,
#   61,
#   318,
#   1,
#   319,
#   320,
#   12,
#   4,
#   14,
#   3,
#   6,
#   137,
#   29,
#   1,
#   321,
#   11,
#   322,
#   323,
#   156,
#   10,
#   19,
#   21,
#   130,
#   4,
#   13,
#   324,
#   83,
#   75,
#   10,
#   19,
#   21,
#   325,
#   326,
#   327,
#   114,
#   12,
#   328,
#   10,
#   41,
#   9,
#   329,
#   330,
#   8,
#   18,
#   147,
#   9,
#   331],
#  [69, 1],
#  [69, 1, 157],
#  [69, 1, 157, 4],
#  [69, 1, 157, 4, 20],
#  [69, 1, 157, 4, 20, 26],
#  [69, 1, 157, 4, 20, 26, 332],
#  [69, 1, 157, 4, 20, 26, 332, 8],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69, 333],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69, 333, 334],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69, 333, 334, 93],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69, 333, 334, 93, 31],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69, 333, 334, 93, 31, 113],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69, 333, 334, 93, 31, 113, 25],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69, 333, 334, 93, 31, 113, 25, 9],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69, 333, 334, 93, 31, 113, 25, 9, 335],
#  [69, 1, 157, 4, 20, 26, 332, 8, 69, 333, 334, 93, 31, 113, 25, 9, 335, 3],
#  [69,
#   1,
#   157,
#   4,
#   20,
#   26,
#   332,
#   8,
#   69,
#   333,
#   334,
#   93,
#   31,
#   113,
#   25,
#   9,
#   335,
#   3,
#   336],
#  [22, 27],
#  [22, 27, 16],
#  [22, 27, 16, 337],
#  [22, 27, 16, 337, 143],
#  [22, 27, 16, 337, 143, 1],
#  [22, 27, 16, 337, 143, 1, 25],
#  [22, 27, 16, 337, 143, 1, 25, 338],
#  [22, 27, 16, 337, 143, 1, 25, 338, 90],
#  [22, 27, 16, 337, 143, 1, 25, 338, 90, 339],
#  [22, 27, 16, 337, 143, 1, 25, 338, 90, 339, 340],
#  [22, 27, 16, 337, 143, 1, 25, 338, 90, 339, 340, 69],
#  [22, 27, 16, 337, 143, 1, 25, 338, 90, 339, 340, 69, 1],
#  [22, 27, 16, 337, 143, 1, 25, 338, 90, 339, 340, 69, 1, 144],
#  [22, 27, 16, 337, 143, 1, 25, 338, 90, 339, 340, 69, 1, 144, 157],
#  [95, 158],
#  [95, 158, 68],
#  [95, 158, 68, 1],
#  [95, 158, 68, 1, 138],
#  [95, 158, 68, 1, 138, 341],
#  [95, 158, 68, 1, 138, 341, 342],
#  [95, 158, 68, 1, 138, 341, 342, 4],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20, 90],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20, 90, 66],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20, 90, 66, 343],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20, 90, 66, 343, 344],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20, 90, 66, 343, 344, 345],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20, 90, 66, 343, 344, 345, 61],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20, 90, 66, 343, 344, 345, 61, 95],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20, 90, 66, 343, 344, 345, 61, 95, 346],
#  [95, 158, 68, 1, 138, 341, 342, 4, 20, 90, 66, 343, 344, 345, 61, 95, 346, 1],
#  [95,
#   158,
#   68,
#   1,
#   138,
#   341,
#   342,
#   4,
#   20,
#   90,
#   66,
#   343,
#   344,
#   345,
#   61,
#   95,
#   346,
#   1,
#   28],
#  [347, 36],
#  [347, 36, 348],
#  [347, 36, 348, 1],
#  [347, 36, 348, 1, 141],
#  [347, 36, 348, 1, 141, 22],
#  [347, 36, 348, 1, 141, 22, 26],
#  [347, 36, 348, 1, 141, 22, 26, 349],
#  [347, 36, 348, 1, 141, 22, 26, 349, 8],
#  [347, 36, 348, 1, 141, 22, 26, 349, 8, 350],
#  [347, 36, 348, 1, 141, 22, 26, 349, 8, 350, 60],
#  [347, 36, 348, 1, 141, 22, 26, 349, 8, 350, 60, 29],
#  [351, 1],
#  [351, 1, 352],
#  [351, 1, 352, 4],
#  [351, 1, 352, 4, 20],
#  [351, 1, 352, 4, 20, 26],
#  [351, 1, 352, 4, 20, 26, 112],
#  [351, 1, 352, 4, 20, 26, 112, 353],
#  [351, 1, 352, 4, 20, 26, 112, 353, 16],
#  [351, 1, 352, 4, 20, 26, 112, 353, 16, 354],
#  [351, 1, 352, 4, 20, 26, 112, 353, 16, 354, 355],
#  [351, 1, 352, 4, 20, 26, 112, 353, 16, 354, 355, 20],
#  [351, 1, 352, 4, 20, 26, 112, 353, 16, 354, 355, 20, 63],
#  [351, 1, 352, 4, 20, 26, 112, 353, 16, 354, 355, 20, 63, 127],
#  [351, 1, 352, 4, 20, 26, 112, 353, 16, 354, 355, 20, 63, 127, 356],
#  [351, 1, 352, 4, 20, 26, 112, 353, 16, 354, 355, 20, 63, 127, 356, 8],
#  [351, 1, 352, 4, 20, 26, 112, 353, 16, 354, 355, 20, 63, 127, 356, 8, 357],
#  [351,
#   1,
#   352,
#   4,
#   20,
#   26,
#   112,
#   353,
#   16,
#   354,
#   355,
#   20,
#   63,
#   127,
#   356,
#   8,
#   357,
#   58],
#  [351,
#   1,
#   352,
#   4,
#   20,
#   26,
#   112,
#   353,
#   16,
#   354,
#   355,
#   20,
#   63,
#   127,
#   356,
#   8,
#   357,
#   58,
#   358],
#  [351,
#   1,
#   352,
#   4,
#   20,
#   26,
#   112,
#   353,
#   16,
#   354,
#   355,
#   20,
#   63,
#   127,
#   356,
#   8,
#   357,
#   58,
#   358,
#   359],
#  [351,
#   1,
#   352,
#   4,
#   20,
#   26,
#   112,
#   353,
#   16,
#   354,
#   355,
#   20,
#   63,
#   127,
#   356,
#   8,
#   357,
#   58,
#   358,
#   359,
#   1],
#  [351,
#   1,
#   352,
#   4,
#   20,
#   26,
#   112,
#   353,
#   16,
#   354,
#   355,
#   20,
#   63,
#   127,
#   356,
#   8,
#   357,
#   58,
#   358,
#   359,
#   1,
#   360],
#  [351,
#   1,
#   352,
#   4,
#   20,
#   26,
#   112,
#   353,
#   16,
#   354,
#   355,
#   20,
#   63,
#   127,
#   356,
#   8,
#   357,
#   58,
#   358,
#   359,
#   1,
#   360,
#   63],
#  [351,
#   1,
#   352,
#   4,
#   20,
#   26,
#   112,
#   353,
#   16,
#   354,
#   355,
#   20,
#   63,
#   127,
#   356,
#   8,
#   357,
#   58,
#   358,
#   359,
#   1,
#   360,
#   63,
#   361],
#  [111, 11],
#  [111, 11, 362],
#  [111, 11, 362, 1],
#  [111, 11, 362, 1, 363],
#  [111, 11, 362, 1, 363, 36],
#  [111, 11, 362, 1, 363, 36, 364],
#  [111, 11, 362, 1, 363, 36, 364, 26],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11, 366],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11, 366, 367],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11, 366, 367, 1],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11, 366, 367, 1, 57],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11, 366, 367, 1, 57, 5],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11, 366, 367, 1, 57, 5, 4],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11, 366, 367, 1, 57, 5, 4, 14],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11, 366, 367, 1, 57, 5, 4, 14, 3],
#  [111, 11, 362, 1, 363, 36, 364, 26, 365, 11, 366, 367, 1, 57, 5, 4, 14, 3, 6],
#  [111,
#   11,
#   362,
#   1,
#   363,
#   36,
#   364,
#   26,
#   365,
#   11,
#   366,
#   367,
#   1,
#   57,
#   5,
#   4,
#   14,
#   3,
#   6,
#   24],
#  [159, 5],
#  [159, 5, 159],
#  [159, 5, 159, 4],
#  [159, 5, 159, 4, 14],
#  [159, 5, 159, 4, 14, 3],
#  [159, 5, 159, 4, 14, 3, 6],
#  [159, 5, 159, 4, 14, 3, 6, 135],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101, 368],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101, 368, 11],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101, 368, 11, 39],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101, 368, 11, 39, 1],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101, 368, 11, 39, 1, 94],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101, 368, 11, 39, 1, 94, 3],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101, 368, 11, 39, 1, 94, 3, 12],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101, 368, 11, 39, 1, 94, 3, 12, 369],
#  [159, 5, 159, 4, 14, 3, 6, 135, 17, 101, 368, 11, 39, 1, 94, 3, 12, 369, 80],
#  [159,
#   5,
#   159,
#   4,
#   14,
#   3,
#   6,
#   135,
#   17,
#   101,
#   368,
#   11,
#   39,
#   1,
#   94,
#   3,
#   12,
#   369,
#   80,
#   57],
#  [159,
#   5,
#   159,
#   4,
#   14,
#   3,
#   6,
#   135,
#   17,
#   101,
#   368,
#   11,
#   39,
#   1,
#   94,
#   3,
#   12,
#   369,
#   80,
#   57,
#   1],
#  [159,
#   5,
#   159,
#   4,
#   14,
#   3,
#   6,
#   135,
#   17,
#   101,
#   368,
#   11,
#   39,
#   1,
#   94,
#   3,
#   12,
#   369,
#   80,
#   57,
#   1,
#   10],
#  [159,
#   5,
#   159,
#   4,
#   14,
#   3,
#   6,
#   135,
#   17,
#   101,
#   368,
#   11,
#   39,
#   1,
#   94,
#   3,
#   12,
#   369,
#   80,
#   57,
#   1,
#   10,
#   19],
#  [159,
#   5,
#   159,
#   4,
#   14,
#   3,
#   6,
#   135,
#   17,
#   101,
#   368,
#   11,
#   39,
#   1,
#   94,
#   3,
#   12,
#   369,
#   80,
#   57,
#   1,
#   10,
#   19,
#   21],
#  [89, 370],
#  [89, 370, 2],
#  [89, 370, 2, 78],
#  [89, 370, 2, 78, 7],
#  [89, 370, 2, 78, 7, 122],
#  [89, 370, 2, 78, 7, 122, 45],
#  [89, 370, 2, 78, 7, 122, 45, 13],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20, 48],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20, 48, 118],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20, 48, 118, 371],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20, 48, 118, 371, 59],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20, 48, 118, 371, 59, 5],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20, 48, 118, 371, 59, 5, 40],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20, 48, 118, 371, 59, 5, 40, 3],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20, 48, 118, 371, 59, 5, 40, 3, 6],
#  [89, 370, 2, 78, 7, 122, 45, 13, 4, 20, 48, 118, 371, 59, 5, 40, 3, 6, 34],
#  [89,
#   370,
#   2,
#   78,
#   7,
#   122,
#   45,
#   13,
#   4,
#   20,
#   48,
#   118,
#   371,
#   59,
#   5,
#   40,
#   3,
#   6,
#   34,
#   88],
#  [89,
#   370,
#   2,
#   78,
#   7,
#   122,
#   45,
#   13,
#   4,
#   20,
#   48,
#   118,
#   371,
#   59,
#   5,
#   40,
#   3,
#   6,
#   34,
#   88,
#   154],
#  [89,
#   370,
#   2,
#   78,
#   7,
#   122,
#   45,
#   13,
#   4,
#   20,
#   48,
#   118,
#   371,
#   59,
#   5,
#   40,
#   3,
#   6,
#   34,
#   88,
#   154,
#   152],
#  [89,
#   370,
#   2,
#   78,
#   7,
#   122,
#   45,
#   13,
#   4,
#   20,
#   48,
#   118,
#   371,
#   59,
#   5,
#   40,
#   3,
#   6,
#   34,
#   88,
#   154,
#   152,
#   1],
#  [89,
#   370,
#   2,
#   78,
#   7,
#   122,
#   45,
#   13,
#   4,
#   20,
#   48,
#   118,
#   371,
#   59,
#   5,
#   40,
#   3,
#   6,
#   34,
#   88,
#   154,
#   152,
#   1,
#   15],
#  [372, 373],
#  [372, 373, 29],
#  [372, 373, 29, 27],
#  [372, 373, 29, 27, 16],
#  [372, 373, 29, 27, 16, 156],
#  [372, 373, 29, 27, 16, 156, 10],
#  [372, 373, 29, 27, 16, 156, 10, 19],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21, 69],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21, 69, 1],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21, 69, 1, 95],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21, 69, 1, 95, 158],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21, 69, 1, 95, 158, 374],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21, 69, 1, 95, 158, 374, 375],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21, 69, 1, 95, 158, 374, 375, 11],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21, 69, 1, 95, 158, 374, 375, 11, 376],
#  [372, 373, 29, 27, 16, 156, 10, 19, 21, 69, 1, 95, 158, 374, 375, 11, 376, 2],
#  [372,
#   373,
#   29,
#   27,
#   16,
#   156,
#   10,
#   19,
#   21,
#   69,
#   1,
#   95,
#   158,
#   374,
#   375,
#   11,
#   376,
#   2,
#   47],
#  [372,
#   373,
#   29,
#   27,
#   16,
#   156,
#   10,
#   19,
#   21,
#   69,
#   1,
#   95,
#   158,
#   374,
#   375,
#   11,
#   376,
#   2,
#   47,
#   7],
#  [372,
#   373,
#   29,
#   27,
#   16,
#   156,
#   10,
#   19,
#   21,
#   69,
#   1,
#   95,
#   158,
#   374,
#   375,
#   11,
#   376,
#   2,
#   47,
#   7,
#   2],
#  [372,
#   373,
#   29,
#   27,
#   16,
#   156,
#   10,
#   19,
#   21,
#   69,
#   1,
#   95,
#   158,
#   374,
#   375,
#   11,
#   376,
#   2,
#   47,
#   7,
#   2,
#   377],
#  [372,
#   373,
#   29,
#   27,
#   16,
#   156,
#   10,
#   19,
#   21,
#   69,
#   1,
#   95,
#   158,
#   374,
#   375,
#   11,
#   376,
#   2,
#   47,
#   7,
#   2,
#   377,
#   5],
#  [372,
#   373,
#   29,
#   27,
#   16,
#   156,
#   10,
#   19,
#   21,
#   69,
#   1,
#   95,
#   158,
#   374,
#   375,
#   11,
#   376,
#   2,
#   47,
#   7,
#   2,
#   377,
#   5,
#   4],
#  [372,
#   373,
#   29,
#   27,
#   16,
#   156,
#   10,
#   19,
#   21,
#   69,
#   1,
#   95,
#   158,
#   374,
#   375,
#   11,
#   376,
#   2,
#   47,
#   7,
#   2,
#   377,
#   5,
#   4,
#   14],
#  [372,
#   373,
#   29,
#   27,
#   16,
#   156,
#   10,
#   19,
#   21,
#   69,
#   1,
#   95,
#   158,
#   374,
#   375,
#   11,
#   376,
#   2,
#   47,
#   7,
#   2,
#   377,
#   5,
#   4,
#   14,
#   3],
#  [372,
#   373,
#   29,
#   27,
#   16,
#   156,
#   10,
#   19,
#   21,
#   69,
#   1,
#   95,
#   158,
#   374,
#   375,
#   11,
#   376,
#   2,
#   47,
#   7,
#   2,
#   377,
#   5,
#   4,
#   14,
#   3,
#   6],
#  [12, 378],
#  [12, 378, 106],
#  [12, 378, 106, 1],
#  [12, 378, 106, 1, 379],
#  [12, 378, 106, 1, 379, 4],
#  [12, 378, 106, 1, 379, 4, 13],
#  [12, 378, 106, 1, 379, 4, 13, 26],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380, 8],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380, 8, 381],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380, 8, 381, 82],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380, 8, 381, 82, 382],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380, 8, 381, 82, 382, 61],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380, 8, 381, 82, 382, 61, 109],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380, 8, 381, 82, 382, 61, 109, 5],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380, 8, 381, 82, 382, 61, 109, 5, 383],
#  [12, 378, 106, 1, 379, 4, 13, 26, 380, 8, 381, 82, 382, 61, 109, 5, 383, 2],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155,
#   7],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155,
#   7,
#   98],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155,
#   7,
#   98,
#   23],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155,
#   7,
#   98,
#   23,
#   71],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155,
#   7,
#   98,
#   23,
#   71,
#   1],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155,
#   7,
#   98,
#   23,
#   71,
#   1,
#   384],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155,
#   7,
#   98,
#   23,
#   71,
#   1,
#   384,
#   3],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155,
#   7,
#   98,
#   23,
#   71,
#   1,
#   384,
#   3,
#   14],
#  [12,
#   378,
#   106,
#   1,
#   379,
#   4,
#   13,
#   26,
#   380,
#   8,
#   381,
#   82,
#   382,
#   61,
#   109,
#   5,
#   383,
#   2,
#   155,
#   7,
#   98,
#   23,
#   71,
#   1,
#   384,
#   3,
#   14,
#   15],
#  [386, 387],
#  [386, 387, 388],
#  [386, 387, 388, 160],
#  [386, 387, 388, 160, 389],
#  [386, 387, 388, 160, 389, 10],
#  [386, 387, 388, 160, 389, 10, 70],
#  [386, 387, 388, 160, 389, 10, 70, 19],
#  [386, 387, 388, 160, 389, 10, 70, 19, 28],
#  [386, 387, 388, 160, 389, 10, 70, 19, 28, 33],
#  [386, 387, 388, 160, 389, 10, 70, 19, 28, 33, 390],
#  [386, 387, 388, 160, 389, 10, 70, 19, 28, 33, 390, 391],
#  [386, 387, 388, 160, 389, 10, 70, 19, 28, 33, 390, 391, 392],
#  [386, 387, 388, 160, 389, 10, 70, 19, 28, 33, 390, 391, 392, 393],
#  [386, 387, 388, 160, 389, 10, 70, 19, 28, 33, 390, 391, 392, 393, 394],
#  [395, 17],
#  [395, 17, 396],
#  [395, 17, 396, 94],
#  [395, 17, 396, 94, 41],
#  [395, 17, 396, 94, 41, 12],
#  [395, 17, 396, 94, 41, 12, 45],
#  [395, 17, 396, 94, 41, 12, 45, 33],
#  [395, 17, 396, 94, 41, 12, 45, 33, 13],
#  [395, 17, 396, 94, 41, 12, 45, 33, 13, 37],
#  [395, 17, 396, 94, 41, 12, 45, 33, 13, 37, 96],
#  [395, 17, 396, 94, 41, 12, 45, 33, 13, 37, 96, 37],
#  [395, 17, 396, 94, 41, 12, 45, 33, 13, 37, 96, 37, 397],
#  [395, 17, 396, 94, 41, 12, 45, 33, 13, 37, 96, 37, 397, 398],
#  [399, 17],
#  [399, 17, 161],
#  [399, 17, 161, 161],
#  [399, 17, 161, 161, 162],
#  [399, 17, 161, 161, 162, 400],
#  [399, 17, 161, 161, 162, 400, 401],
#  [399, 17, 161, 161, 162, 400, 401, 1],
#  [399, 17, 161, 161, 162, 400, 401, 1, 57],
#  [399, 17, 161, 161, 162, 400, 401, 1, 57, 45],
#  [399, 17, 161, 161, 162, 400, 401, 1, 57, 45, 13],
#  [399, 17, 161, 161, 162, 400, 401, 1, 57, 45, 13, 37],
#  [399, 17, 161, 161, 162, 400, 401, 1, 57, 45, 13, 37, 96],
#  [399, 17, 161, 161, 162, 400, 401, 1, 57, 45, 13, 37, 96, 37],
#  [399, 17, 161, 161, 162, 400, 401, 1, 57, 45, 13, 37, 96, 37, 402],
#  ...]

# %%
max_len = max([len(x) for x in input_sequence])

# %%
max_len
# Out:
# 52

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
pad_sequence=pad_sequences(input_sequence,maxlen=max_len,padding='pre')

# %%
pad_sequence
# Out:
# array([[  0,   0,   0, ...,   0,  97,  10],
#        [  0,   0,   0, ...,  97,  10,  70],
#        [  0,   0,   0, ...,  10,  70,  19],
#        ...,
#        [  0,   0,   0, ...,  18,  71,  24],
#        [  0,   0,   0, ...,  71,  24, 430],
#        [  0,   0,   0, ...,  24, 430, 431]], dtype=int32)

# %%
x=pad_sequence[:,:-1]

# %%
y=pad_sequence[:,-1]

# %%
x.shape
# Out:
# (1051, 51)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=432)

# %%
y.shape
# Out:
# (1051, 432)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model=Sequential()
model.add(Embedding(432,100,input_length=51))
model.add(LSTM(150))
model.add(Dense(432,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 51, 100)           43200
#
#  lstm_1 (LSTM)               (None, 150)               150600
#
#  dense_1 (Dense)             (None, 432)               65232
#
# =================================================================
# Total params: 259032 (1011.84 KB)
# Trainable params: 259032 (1011.84 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 7s 131ms/step - loss: 5.9053 - accuracy: 0.0257
# Epoch 2/100
# 33/33 [==============================] - 2s 74ms/step - loss: 5.5784 - accuracy: 0.0457
# Epoch 3/100
# 33/33 [==============================] - 2s 54ms/step - loss: 5.4742 - accuracy: 0.0466
# Epoch 4/100
# 33/33 [==============================] - 2s 53ms/step - loss: 5.4391 - accuracy: 0.0419
# Epoch 5/100
# 33/33 [==============================] - 1s 40ms/step - loss: 5.3835 - accuracy: 0.0476
# Epoch 6/100
# 33/33 [==============================] - 1s 40ms/step - loss: 5.2782 - accuracy: 0.0609
# Epoch 7/100
# 33/33 [==============================] - 1s 22ms/step - loss: 5.1322 - accuracy: 0.0799
# Epoch 8/100
# 33/33 [==============================] - 0s 7ms/step - loss: 4.9416 - accuracy: 0.0837
# Epoch 9/100
# 33/33 [==============================] - 1s 20ms/step - loss: 4.7018 - accuracy: 0.1104
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 4.4390 - accuracy: 0.1304
# Epoch 11/100
# 33/33 [==============================] - 1s 15ms/step - loss: 4.1634 - accuracy: 0.1732
# Epoch 12/100
# 33/33 [==============================] - 1s 26ms/step - loss: 3.8743 - accuracy: 0.2055
# Epoch 13/100
# 33/33 [==============================] - 0s 8ms/step - loss: 3.6102 - accuracy: 0.2312
# Epoch 14/100
# 33/33 [==============================] - 1s 32ms/step - loss: 3.3421 - accuracy: 0.2883
# Epoch 15/100
# 33/33 [==============================] - 1s 24ms/step - loss: 3.0901 - accuracy: 0.3283
# Epoch 16/100
# 33/33 [==============================] - 0s 9ms/step - loss: 2.8633 - accuracy: 0.3711
# Epoch 17/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.6467 - accuracy: 0.4177
# Epoch 18/100
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4411 - accuracy: 0.4634
# Epoch 19/100
# 33/33 [==============================] - 0s 7ms/step - loss: 2.2519 - accuracy: 0.5214
# Epoch 20/100
# 33/33 [==============================] - 0s 6ms/step - loss: 2.0738 - accuracy: 0.5842
# Epoch 21/100
# 33/33 [==============================] - 0s 11ms/step - loss: 1.9043 - accuracy: 0.6156
# Epoch 22/100
# 33/33 [==============================] - 1s 25ms/step - loss: 1.7500 - accuracy: 0.6879
# Epoch 23/100
# 33/33 [==============================] - 0s 11ms/step - loss: 1.6097 - accuracy: 0.7364
# Epoch 24/100
# 33/33 [==============================] - 0s 6ms/step - loss: 1.4800 - accuracy: 0.7621
# Epoch 25/100
# 33/33 [==============================] - 0s 6ms/step - loss: 1.3521 - accuracy: 0.8126
# Epoch 26/100
# 33/33 [==============================] - 0s 6ms/step - loss: 1.2469 - accuracy: 0.8344
# Epoch 27/100
# 33/33 [==============================] - 0s 6ms/step - loss: 1.1504 - accuracy: 0.8487
# Epoch 28/100
# 33/33 [==============================] - 0s 6ms/step - loss: 1.0509 - accuracy: 0.8801
# Epoch 29/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.9588 - accuracy: 0.8934
# Epoch 30/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.8860 - accuracy: 0.9163
# Epoch 31/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.8194 - accuracy: 0.9220
# Epoch 32/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.7486 - accuracy: 0.9410
# Epoch 33/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.6905 - accuracy: 0.9458
# Epoch 34/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.6352 - accuracy: 0.9562
# Epoch 35/100
# 33/33 [==============================] - 0s 11ms/step - loss: 0.5834 - accuracy: 0.9591
# Epoch 36/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.5407 - accuracy: 0.9657
# Epoch 37/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4999 - accuracy: 0.9724
# Epoch 38/100
# 33/33 [==============================] - 0s 11ms/step - loss: 0.4644 - accuracy: 0.9791
# Epoch 39/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4289 - accuracy: 0.9762
# Epoch 40/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3971 - accuracy: 0.9791
# Epoch 41/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3690 - accuracy: 0.9829
# Epoch 42/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3436 - accuracy: 0.9857
# Epoch 43/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3196 - accuracy: 0.9857
# Epoch 44/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2978 - accuracy: 0.9848
# Epoch 45/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2796 - accuracy: 0.9895
# Epoch 46/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2604 - accuracy: 0.9876
# Epoch 47/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2431 - accuracy: 0.9905
# Epoch 48/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2295 - accuracy: 0.9924
# Epoch 49/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2168 - accuracy: 0.9943
# Epoch 50/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2042 - accuracy: 0.9905
# Epoch 51/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1908 - accuracy: 0.9943
# Epoch 52/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1809 - accuracy: 0.9933
# Epoch 53/100
# 33/33 [==============================] - 0s 15ms/step - loss: 0.1720 - accuracy: 0.9952
# Epoch 54/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1614 - accuracy: 0.9914
# Epoch 55/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1533 - accuracy: 0.9933
# Epoch 56/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1456 - accuracy: 0.9933
# Epoch 57/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.1378 - accuracy: 0.9943
# Epoch 58/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1313 - accuracy: 0.9933
# Epoch 59/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1260 - accuracy: 0.9933
# Epoch 60/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1201 - accuracy: 0.9924
# Epoch 61/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1142 - accuracy: 0.9914
# Epoch 62/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1083 - accuracy: 0.9952
# Epoch 63/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1036 - accuracy: 0.9933
# Epoch 64/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0992 - accuracy: 0.9924
# Epoch 65/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0958 - accuracy: 0.9924
# Epoch 66/100
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0914 - accuracy: 0.9933
# Epoch 67/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0883 - accuracy: 0.9914
# Epoch 68/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0852 - accuracy: 0.9924
# Epoch 69/100
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0819 - accuracy: 0.9962
# Epoch 70/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0797 - accuracy: 0.9952
# Epoch 71/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0755 - accuracy: 0.9933
# Epoch 72/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0730 - accuracy: 0.9914
# Epoch 73/100
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0712 - accuracy: 0.9933
# Epoch 74/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0678 - accuracy: 0.9933
# Epoch 75/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0654 - accuracy: 0.9952
# Epoch 76/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0634 - accuracy: 0.9943
# Epoch 77/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0611 - accuracy: 0.9952
# Epoch 78/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0584 - accuracy: 0.9943
# Epoch 79/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0577 - accuracy: 0.9952
# Epoch 80/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0556 - accuracy: 0.9952
# Epoch 81/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0535 - accuracy: 0.9943
# Epoch 82/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0519 - accuracy: 0.9933
# Epoch 83/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0509 - accuracy: 0.9952
# Epoch 84/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0486 - accuracy: 0.9952
# Epoch 85/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0484 - accuracy: 0.9952
# Epoch 86/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0456 - accuracy: 0.9962
# Epoch 87/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0451 - accuracy: 0.9943
# Epoch 88/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0444 - accuracy: 0.9943
# Epoch 89/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0434 - accuracy: 0.9952
# Epoch 90/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0410 - accuracy: 0.9952
# Epoch 91/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0406 - accuracy: 0.9943
# Epoch 92/100
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0395 - accuracy: 0.9933
# Epoch 93/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0382 - accuracy: 0.9943
# Epoch 94/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0375 - accuracy: 0.9933
# Epoch 95/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0369 - accuracy: 0.9933
# Epoch 96/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0353 - accuracy: 0.9933
# Epoch 97/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0351 - accuracy: 0.9933
# Epoch 98/100
# 33/33 [==============================] - 0s 15ms/step - loss: 0.0343 - accuracy: 0.9962
# Epoch 99/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0331 - accuracy: 0.9943
# Epoch 100/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0325 - accuracy: 0.9933

# %%
import numpy as np

# %%
tokenizer.word_index.items()
# Out:
# dict_items([('and', 1), ('the', 2), ('text', 3), ('lstm', 4), ('in', 5), ('prediction', 6), ('of', 7), ('to', 8), ('or', 9), ('long', 10), ('for', 11), ('with', 12), ('networks', 13), ('based', 14), ('applications', 15), ('as', 16), ('a', 17), ('information', 18), ('term', 19), ('models', 20), ('dependencies', 21), ('techniques', 22), ('language', 23), ('systems', 24), ('data', 25), ('are', 26), ('such', 27), ('memory', 28), ('challenges', 29), ('next', 30), ('on', 31), ('learning', 32), ('neural', 33), ('tasks', 34), ('gates', 35), ('model', 36), ('arxiv', 37), ('from', 38), ('modeling', 39), ('various', 40), ('sequences', 41), ('word', 42), ('including', 43), ('translation', 44), ('recurrent', 45), ('cell', 46), ('state', 47), ('have', 48), ('methodologies', 49), ('predicting', 50), ('machine', 51), ('speech', 52), ('sentiment', 53), ('analysis', 54), ('n', 55), ('which', 56), ('understanding', 57), ('their', 58), ('performance', 59), ('these', 60), ('significant', 61), ('architecture', 62), ('making', 63), ('network', 64), ('input', 65), ('be', 66), ('time', 67), ('training', 68), ('overfitting', 69), ('short', 70), ('processing', 71), ('nlp', 72), ('task', 73), ('autocomplete', 74), ('capturing', 75), ('range', 76), ('over', 77), ('principles', 78), ('recognition', 79), ('contextual', 80), ('capture', 81), ('an', 82), ('at', 83), ('output', 84), ('gate', 85), ('determines', 86), ('should', 87), ('across', 88), ('by', 89), ('can', 90), ('using', 91), ('tuning', 92), ('trained', 93), ('generating', 94), ('computational', 95), ('preprint', 96), ('exploring', 97), ('natural', 98), ('predictive', 99), ('among', 100), ('powerful', 101), ('preserving', 102), ('context', 103), ('extended', 104), ('this', 105), ('research', 106), ('sequence', 107), ('given', 108), ('role', 109), ('traditional', 110), ('methods', 111), ('often', 112), ('limited', 113), ('struggle', 114), ('within', 115), ('rnns', 116), ('variants', 117), ('demonstrated', 118), ('attention', 119), ('gradient', 120), ('sequential', 121), ('gated', 122), ('them', 123), ('well', 124), ('suited', 125), ('forget', 126), ('it', 127), ('retain', 128), ('relevant', 129), ('while', 130), ('out', 131), ('key', 132), ('include', 133), ('current', 134), ('represents', 135), ('through', 136), ('several', 137), ('deploying', 138), ('tokenization', 139), ('bptt', 140), ('optimization', 141), ('rate', 142), ('dropout', 143), ('improve', 144), ('evaluation', 145), ('metrics', 146), ('loss', 147), ('accuracy', 148), ('fine', 149), ('transfer', 150), ('pre', 151), ('domains', 152), ('phrase', 153), ('different', 154), ('future', 155), ('handling', 156), ('generalization', 157), ('efficiency', 158), ('conclusion', 159), ('j', 160), ('fei', 161), ('l', 162), ('abstract', 163), ('realm', 164), ('stands', 165), ('fundamental', 166), ('ranging', 167), ('typing', 168), ('employed', 169), ('emerged', 170), ('tool', 171), ('capable', 172), ('essay', 173), ('delves', 174), ('into', 175), ('associated', 176), ('its', 177), ('significance', 178), ('modern', 179), ('introduction', 180), ('also', 181), ('known', 182), ('refers', 183), ('words', 184), ('preceding', 185), ('plays', 186), ('pivotal', 187), ('rely', 188), ('statistical', 189), ('gram', 190), ('suffer', 191), ('recent', 192), ('years', 193), ('deep', 194), ('approaches', 195), ('particularly', 196), ('remarkable', 197), ('garnered', 198), ('due', 199), ('ability', 200), ('mitigate', 201), ('vanishing', 202), ('problem', 203), ('offer', 204), ('effective', 205), ('solution', 206), ('complex', 207), ('temporal', 208), ('dynamics', 209), ('type', 210), ('designed', 211), ('overcome', 212), ('limitations', 213), ('core', 214), ('cells', 215), ('equipped', 216), ('regulate', 217), ('flow', 218), ('allowing', 219), ('filtering', 220), ('irrelevant', 221), ('components', 222), ('previous', 223), ('discarded', 224), ('forgotten', 225), ('new', 226), ('stored', 227), ('steps', 228), ('step', 229), ('selectively', 230), ('update', 231), ('propaga ...

# %%
import time
text = "what is LSTM"

for i in range(20):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=51, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# what is LSTM networks
# 1/1 [==============================] - 0s 28ms/step
# what is LSTM networks with
# 1/1 [==============================] - 0s 18ms/step
# what is LSTM networks with their
# 1/1 [==============================] - 0s 21ms/step
# what is LSTM networks with their gated
# 1/1 [==============================] - 0s 19ms/step
# what is LSTM networks with their gated architecture
# 1/1 [==============================] - 0s 18ms/step
# what is LSTM networks with their gated architecture offer
# 1/1 [==============================] - 0s 19ms/step
# what is LSTM networks with their gated architecture offer an
# 1/1 [==============================] - 0s 18ms/step
# what is LSTM networks with their gated architecture offer an effective
# 1/1 [==============================] - 0s 18ms/step
# what is LSTM networks with their gated architecture offer an effective solution
# 1/1 [==============================] - 0s 18ms/step
# what is LSTM networks with their gated architecture offer an effective solution for
# 1/1 [==============================] - 0s 18ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling
# 1/1 [==============================] - 0s 19ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling sequential
# 1/1 [==============================] - 0s 27ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling sequential data
# 1/1 [==============================] - 0s 20ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling sequential data with
# 1/1 [==============================] - 0s 19ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling sequential data with complex
# 1/1 [==============================] - 0s 19ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling sequential data with complex temporal
# 1/1 [==============================] - 0s 18ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling sequential data with complex temporal dynamics
# 1/1 [==============================] - 0s 25ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling sequential data with complex temporal dynamics making
# 1/1 [==============================] - 0s 28ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling sequential data with complex temporal dynamics making them
# 1/1 [==============================] - 0s 18ms/step
# what is LSTM networks with their gated architecture offer an effective solution for modeling sequential data with complex temporal dynamics making them well
